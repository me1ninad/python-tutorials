# %%
from urllib.request import urlretrieve; import pandas as pd

# %%
url_of_file='https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv'
urlretrieve(url_of_file,"winequality-red.csv")
# Out:
# ('winequality-red.csv', <http.client.HTTPMessage at 0x2736371a488>)

# %%
df = pd.read_csv('winequality-red.csv',sep=';')
print(df.head)
# Out:
# <bound method NDFrame.head of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
url_of_file2='https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/'

sub_url_list=[
    'winequality-red.csv',
    'winequality-white.csv',
    'winequality.names'
]

for url_list in sub_url_list:
    urlretrieve(url_of_file2+url_list,str(url_list))
#df=pd.read_csv()

# %%
import matplotlib.pyplot as plt;import pandas as pd
url='https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv'
df = pd.read_csv(url,sep=';')
print(df.head())
pd.DataFrame.hist(df.ix[:,0:1])
plt.xlabel('fixed acidity (g(tartaric acid)/dm$^3$)')
plt.ylabel('count')
plt.show()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
import pandas as pd

url='https://archive.ics.uci.edu/ml/machine-learning-databases/00192/BreastTissue.xls'
xl=pd.read_excel(url,sheet_name=None)
print(xl.keys())
print(xl['Data'].head())

# !pip list
# Out:
# odict_keys(['Description', 'Data'])
#    Case # Class          I0     PA500       HFS          DA          Area  \
# 0       1   car  524.794072  0.187448  0.032114  228.800228   6843.598481
# 1       2   car  330.000000  0.226893  0.265290  121.154201   3163.239472
# 2       3   car  551.879287  0.232478  0.063530  264.804935  11888.391827
# 3       4   car  380.000000  0.240855  0.286234  137.640111   5402.171180
# 4       5   car  362.831266  0.200713  0.244346  124.912559   3290.462446
#
#         A/DA     Max IP          DR           P
# 0  29.910803  60.204880  220.737212  556.828334
# 1  26.109202  69.717361   99.084964  400.225776
# 2  44.894903  77.793297  253.785300  656.769449
# 3  39.248524  88.758446  105.198568  493.701814
# 4  26.342127  69.389389  103.866552  424.796503
# Package                            Version
# ---------------------------------- ---------
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# ...

# %%
from urllib.request import Request,urlopen
url="https://aianalytics.in/"
request=Request(url)
response=urlopen(request)
print("the datatype of response object is:" +str((type(response))))
html=response.read()
print(html)
response.close()
# Out:
# the datatype of response object is:<class 'http.client.HTTPResponse'>
# ...

# %%
from urllib.request import Request,urlopen
url="https://en.wikipedia.org/wiki/Zinedine_Zidane"
request=Request(url)
response=urlopen(request)
print("the datatype of response object is:" +str((type(response))))
html=response.read()
print(html)
response.close()
# Out:
# the datatype of response object is:<class 'http.client.HTTPResponse'>
# ...

# %%
#!pip install BeautifulSoup4
import requests
from bs4 import BeautifulSoup
url='https://www.clarks.co.uk/c/Dancer-Reece/p/26137864'
r=requests.get(url)
html_doc=r.text
soup=BeautifulSoup(html_doc)
prettify_soup=soup.prettify()
print(prettify_soup)
# Out:
# <!DOCTYPE html>
# <html lang="en-gb">
#  <head>
#   <script>
#    var monetateT = new Date().getTime();
#   </script>
#   <script data-consent-category="2" src="https://se.monetate.net/js/2/a-59fa0bba/p/clarks.co.uk/entry.js">
#   </script>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="max-age=0" http-equiv="cache-control"/>
#   <meta content="no-cache" http-equiv="cache-control"/>
#   <meta content="-1" http-equiv="expires"/>
#   <meta content="no-cache" http-equiv="pragma"/>
#   <meta content="pangaea2-release-1.0.0.310" name="build-number"/>
#   <meta name="keywords"/>
# ...

# %%
#!pip install BeautifulSoup4
import requests
from bs4 import BeautifulSoup
url='https://en.wikipedia.org/wiki/Zinedine_Zidane'
r=requests.get(url)
html_doc=r.text
#soup=BeautifulSoup(html_doc)
#prettify_soup=soup.prettify()
#print(prettify_soup)

soup = BeautifulSoup(html_doc,"html.parser")
guido_title=soup.title
guido_text=soup.get_text()
p_tags=soup.find_all('b')
for tex in p_tags:
    print(guido_text)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
import requests
r=requests.get(url)
text=r.text
print(text)
# Out:
# <!DOCTYPE html>
# <html lang="en-gb">
# <head>
#     <script>var monetateT = new Date().getTime();</script>
#     <script src="https://se.monetate.net/js/2/a-59fa0bba/p/clarks.co.uk/entry.js" data-consent-category="2"></script>
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <meta http-equiv="cache-control" content="max-age=0"/>
#     <meta http-equiv="cache-control" content="no-cache"/>
#     <meta http-equiv="expires" content="-1"/>
#     <meta http-equiv="pragma" content="no-cache"/>
#
#     <meta name="build-number" content="pangaea2-release-1.0.0.310"/>
#     <meta name="keywords">
# ...

# %%
soup = BeautifulSoup(html_doc,"html.parser")
guido_title=soup.title
guido_text=soup.get_text()
a_tags=soup.find_all('a')
for link in a_tags:
    print(link.get('href'))
# Out:
# None
# #page
# /track-order
# /store-locator
# /my-account
# /logout
# /login
# /
# /cart
# /cart
# https://www.clarks.co.uk/Black-Friday/c/308?q=:relevance:department:womens&sort=relevance
# https://www.clarks.co.uk/Black-Friday/c/308?q=:relevance:department:mens&sort=relevance
# /Kids/Kids-Shoe-Offers-/c/k23
# https://www.clarks.co.uk/Black-Friday/c/308?q=:relevance:department:womens&sort=relevance
# https://www.clarks.co.uk/womens
# https://www.clarks.co.uk/Womens/All-Styles/c/w2
# https://www.clarks.co.uk/Womens/New-Arrivals/c/w16
# https://www.clarks.co.uk/find-your-style/womens-boots
# https://www.clarks.co.uk/Womens/Boots/c/w50
# https://www.clarks.co.uk/Womens/Boots/Ankle-Boots/c/w51
# /Womens/Boots/Biker-Boots/c/w63
# https://www.clarks.co.uk/Womens/Boots/Brown-and-Tan/c/ukw26
# https://www.clarks.co.uk/Womens/Boots/Chelsea-Boots/c/w52
# https://www.clarks.co.uk/Womens/Gore-Tex/c/w89?q=:relevance:productType:boots&sort=relevance
# ...
